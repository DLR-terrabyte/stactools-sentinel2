# %% [markdown]
# # Problem
# Some S2 tiles create an error when STAC metadata is created using the terrabyte ingestion lib based on stactools sentinel-2. It is related to crossing the antimeridian. Here's a documentation of the problem.

# %% [markdown]
# ## Inputs

# %%
import os
scene_path = "/dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CT/2023/04/S2A_MSIL2A_20230409T002611_N0509_R102_T01WCT_20230409T040056.SAFE"
scene_id = os.path.splitext(os.path.basename(scene_path))[0]
scene_id
# Out:
# 'S2A_MSIL2A_20230409T002611_N0509_R102_T01WCT_20230409T040056'

# %% [markdown]
# ## Using terrabyte ingestion lib
# ```
# metadata_error: Error during creating metadata for /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CT/2023/04/S2A_MSIL2A_20230409T002611_N0509_R102_T01WCT_20230409T040056.SAFE: Area of geometry is 64800.0, which is too large to be correct.
# ```

# %%
from terrabyte.ingestion.datasets import sentinel

# %%
stac_file = sentinel.sentinel_metadata(scene_path, scene_id)
# Out:
# executing sentinel_metadata for /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CT/2023/04/S2A_MSIL2A_20230409T002611_N0509_R102_T01WCT_20230409T040056.SAFE
# /dss/dsshome1/06/di38laz/micromamba/envs/s2_dateline/lib/python3.13/site-packages/antimeridian/_implementation.py:441: FixWindingWarning: The exterior ring of this shape is wound clockwise. Since this is a common error in real-world geometries, this package is reversing the exterior coordinates of the input shape before running its algorithm. If you know that your input shape is correct (i.e. if your data encompasses both poles), pass `fix_winding=False`.
#   FixWindingWarning.warn()
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# File ~/micromamba/envs/s2_dateline/lib/python3.13/site-packages/terrabyte/ingestion/datasets/sentinel.py:231, in sentinel_metadata(scene_path, scene_id, return_pystac, add_file_size)
#     230 stac_file = os.path.join(scene_path, scene_id + ".STAC.json")
# --> 231 stac_item = extract_stactools(scene_path, stac_function, stac_function_args)
#     232 stac_item.properties['terrabyte:stactools_id'] = stac_item.id
#
# File ~/micromamba/envs/s2_dateline/lib/python3.13/site-packages/terrabyte/ingestion/metadata/stac.py:34, in extract_stactools(scene_path, function_name, stac_function_options)
#      33 def extract_stactools(scene_path: str, function_name: str, stac_function_options: dict):
# ---> 34     stac_item = extract_by_function_name(scene_path, function_name, stac_function_options)
#      35     if "created" not in stac_item.properties:
#
# File ~/micromamba/envs/s2_dateline/lib/python3.13/site-packages/terrabyte/ingestion/metadata/stac.py:31, in extract_by_function_name(scene_path, function_name, stac_function_options)
#      29 metadata_function = getattr(mod, func_name)
# ---> 31 return metadata_function(scene_path, **stac_function_options)
#
# File ~/micromamba/envs/s2_dateline/lib/python3.13/site-packages/stactools/sentinel2/stac.py:145, in create_item(granule_href, tolerance, additional_providers, read_href_modifier, asset_href_prefix)
#     144 if (ga := geometry.area) > 100:
# --> 145     raise Exception(f"Area of geometry is {ga}, which is too large to be correct.")
#     147 bbox = [round(v, COORD_ROUNDING) for v in antimeridian.bbox(geometry)]
#
# Exception: Area of geometry is 64800.0, which is too large to be correct.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 stac_file = sentinel.sentinel_metadata(scene_path, scene_id)
#
# File ~/micromamba/envs/s2_dateline/lib/python3.13/site-packages/terrabyte/ingestion/datasets/sentinel.py:265, in sentinel_metadata(scene_path, scene_id, return_pystac, add_file_size)
#     260 except Exception as e:
#     261     metadata_error = "Error during creating metadata for %s: %s" % (
#     262         scene_path,
#     263         str(e),
#     264     )
# --> 265     raise Exception(
#     266         "metadata_error: %s" % metadata_error
#     267     )
#
# Exception: metadata_error: Error during creating metadata for /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CT/2023/04/S2A_MSIL2A_20230409T002611_N0509_R102_T01WCT_20230409T040056.SAFE: Area of geometry is 64800.0, which is too large to be correct.

# %% [markdown]
# ## Using stactools-sentinel
# Based on https://github.com/DLR-terrabyte/stactools-sentinel2
#
# ```
# Exception: Area of geometry is 64800.0, which is too large to be correct.
# ```

# %%
from stactools.sentinel2.stac import create_item

# %%
stac = create_item(scene_path)
# Out:
# /dss/dsshome1/06/di38laz/micromamba/envs/s2_dateline/lib/python3.13/site-packages/antimeridian/_implementation.py:441: FixWindingWarning: The exterior ring of this shape is wound clockwise. Since this is a common error in real-world geometries, this package is reversing the exterior coordinates of the input shape before running its algorithm. If you know that your input shape is correct (i.e. if your data encompasses both poles), pass `fix_winding=False`.
#   FixWindingWarning.warn()
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 stac = create_item(scene_path)
#
# File ~/micromamba/envs/s2_dateline/lib/python3.13/site-packages/stactools/sentinel2/stac.py:145, in create_item(granule_href, tolerance, additional_providers, read_href_modifier, asset_href_prefix)
#     137 # sometimes, antimeridian and/or polar crossing scenes on some platforms end up
#     138 # with geometries that cover the inverse area that they should, so nearly the
#     139 # entire globe. This has been seen to have different behaviors on different
#    (...)    142 # is unreasonably large. Typical areas will no greater than 3, whereas an
#     143 # incorrect globe-covering geometry will have an area for 61110.
#     144 if (ga := geometry.area) > 100:
# --> 145     raise Exception(f"Area of geometry is {ga}, which is too large to be correct.")
#     147 bbox = [round(v, COORD_ROUNDING) for v in antimeridian.bbox(geometry)]
#     149 item = pystac.Item(
#     150     id=metadata.scene_id,
#     151     geometry=shapely_mapping(geometry),
#    (...)    154     properties={"created": now_to_rfc3339_str()},
#     155 )
#
# Exception: Area of geometry is 64800.0, which is too large to be correct.

# %% [markdown]
# ## Check versions of used packages
# Theoretically the issue should be solved in the stactools sentinel2 package. But the case we experience still occurs. Also with the newest version of the package.
#
# **Issue should be solved**: https://github.com/stactools-packages/sentinel2/issues/149
#
# - Version on conda too old: on conda-forge 27.03.2025
# `+ stactools                                0.5.3  pyhd8ed1ab_0          conda-forge/noarch         47kB`
# - But: DLR Fork uses **new version** including the fix see here: https://github.com/DLR-terrabyte/stactools-sentinel2/
# - It still doesn't fix that problem.
# - Problem is this code part: https://github.com/DLR-terrabyte/stactools-sentinel2/blob/main/src/stactools/sentinel2/stac.py#L137

# %% [markdown]
# ## Check against CDSE
# - https://stac.dataspace.copernicus.eu/v1/collections/sentinel-2-l2a/items/S2A_MSIL2A_20230409T002611_N0509_R102_T01WCT_20230409T040056
# - https://browser.stac.dataspace.copernicus.eu/collections/sentinel-2-l2a/items/S2A_MSIL2A_20230409T002611_N0509_R102_T01WCT_20230409T040056?.language=de

# %%
#bbox_cdse = (-179.99884, 69.247239, 180, 70.277197)
#gdf_cdse = gpd.GeoDataFrame(
#    {"geometry": [box(*bbox_cdse)]}, 
#    crs="EPSG:4326"  # Use the CRS of the dataset
#)
#print(gdf_cdse.total_bounds)
#gdf_cdse.explore()

# %% [markdown]
# # Test: Solution based on inventory mapping solution
# For the inventory maps we had a similar problem to solve:
# https://gitlab.dlr.de/terrabyte/data-management/inventory/terrabyte-inventory-mapping/-/blob/main/dateline_corrections/dateline_corrections_execute.ipynb?ref_type=heads

# %% [markdown]
# ## Micromamba Environment
# `micromamba create -n s2_dateline -c conda-forge gdal python geopandas xarray pandas pyproj numpy folium shapely pip jupyterlab`
#
# `pip install git+https://github.com/DLR-terrabyte/stactools-sentinel2.git`
#
# `pip install git+https://gitlab.dlr.de/terrabyte/data-management/ingestion/terrabyte-ingestion-lib.git`

# %%
import pandas as pd
import geopandas as gpd
import folium
from datetime import datetime
from pytz import UTC
from random import randint
from pyproj import CRS
from shapely import wkt
from shapely.geometry import LineString, MultiPolygon, Polygon
from shapely.ops import split
from math import sqrt
from numpy import sqrt

# %% [markdown]
# ## Functions
# These functions are needed to solve the dateline crossing geomertries:
# - `crosses_dateline()` -> Check if dateline is crossed.
# - `correct_dateline_crossing()` -> Fix the crossing by keeping the larger portion of the geometry intact and cutting at 180.

# %%
def crosses_dateline(geometry):
    """
    Check if a Polygon crosses the dateline (+/-180 degrees) by having both positive and negative longitudes,
    and those longitudes are near 180 degrees. This function excludes crossings near 0 degrees.
    
    Parameters:
    geometry (shapely.geometry.Polygon): A Polygon geometry to check.
    
    Returns:
    Boolean: True if the polygon crosses the dateline (±180 longitude), otherwise False.
    """
    if isinstance(geometry, Polygon):
        # Get the longitudes of the exterior ring
        longitudes = [coord[0] for coord in geometry.exterior.coords]
        
        # Check if there are both positive and negative longitudes
        has_positive = any(lon > 0 for lon in longitudes)
        has_negative = any(lon < 0 for lon in longitudes)

        # Check if the longitudes are near the dateline (close to ±180 degrees)
        near_dateline = any(abs(lon) > 170 for lon in longitudes)

        # The polygon crosses the dateline if it has both positive and negative longitudes,
        # and at least one longitude is close to 180 degrees (±170 or more).
        return has_positive and has_negative and near_dateline
    else:
        return False  # Return False if the geometry is not a Polygon
# Example use: 
# gdf_crossing = gdf[gdf['geometry'].apply(crosses_dateline)]

# %%
def correct_dateline_crossing(geometry):
    """Corrects polygons that cross the dateline. There are 3 possible cases: 
    Case 1: If all longitudes have the same sign, skip the geometry. Return original.
    Case 2: If there's exactly one positive or one negative longitude. Replace the sign.
    Case 3: If there are two positive and two negative longitudes. Calculate distance to 180. Then whichever distance is smaller replace those longitudes with 180 and flip their sign.
    
    Parameters:
    geometry (shapely.geometry.Polygon): A Polygon that needs to be corrected identified by crosses_dateline().

    Returns:
    geometry (shapely.geometry.Polygon): The corrected Polygon, not crossing the dateline anymore.
    
    """
    # Ensure the geometry is a Polygon
    if not isinstance(geometry, Polygon):
        return geometry  
    
    # Extract the longitudes and latitudes from the geometry
    coords = list(geometry.exterior.coords)
    lons = [lon for lon, lat in coords]
    lats = [lat for lon, lat in coords]

    # Ensure the polygon's first and last coordinates are the same
    if coords[0] != coords[-1]:
        raise ValueError("Polygon is not closed properly; first and last coordinates must be identical.")

    # Remove the last coordinate (duplicate of the first)
    lons.pop()
    lats.pop()

    # Check the signs of all longitudes
    pos_lons = [lon for lon in lons if lon > 0]
    neg_lons = [lon for lon in lons if lon < 0]

    # Case 1: If all longitudes have the same sign, skip the geometry
    if len(pos_lons) == 0 or len(neg_lons) == 0:
        return geometry
    
    # Case 2: If there's exactly one positive or one negative longitude
    elif len(pos_lons) == 1:
        # Only one positive longitude, replace it with 180
        new_lons = [-180 if lon > 0 else lon for lon in lons]
    
    elif len(neg_lons) == 1:
        # Only one negative longitude, replace it with -180
        new_lons = [180 if lon < 0 else lon for lon in lons]
    
    # Case 3: If there are two positive and two negative longitudes
    elif len(pos_lons) == 2 and len(neg_lons) == 2:
        # Calculate distances to 180 for positive and negative longitudes
        pos_distances = [180 - lon for lon in pos_lons]
        neg_distances = [abs(-180 + lon) for lon in neg_lons]

        if sum(pos_distances) < sum(neg_distances):
            # Replace positive longitudes with 180 and flip their sign
            new_lons = [180 if lon > 0 else lon for lon in lons]
            new_lons = [-180 if lon == 180 else lon for lon in new_lons]
        else:
            # Replace negative longitudes with -180 and flip their sign
            new_lons = [-180 if lon < 0 else lon for lon in lons]
            new_lons = [180 if lon == -180 else lon for lon in new_lons]
    else:
        # Other cases, return the geometry unchanged
        return geometry

    # Close the polygon loop by adding the first coordinate at the end
    new_coords = [(lon, lat) for lon, lat in zip(new_lons, lats)]
    new_coords.append(new_coords[0])  # Ensure the polygon is closed

    return Polygon(new_coords)

# Example usage:
# Assuming you have a GeoDataFrame 'gdf':
# gdf['geometry'] = gdf['geometry'].apply(correct_dateline_crossing)

# %% [markdown]
# ## Investigate one example in detail
# ### Get metadata

# %%
from osgeo import gdal
import xarray as xr
from shapely.wkt import loads
from shapely.geometry import box

# %%
scene_path
# Out:
# '/dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CT/2023/04/S2A_MSIL2A_20230409T002611_N0509_R102_T01WCT_20230409T040056.SAFE'

# %%
dataset = gdal.Open(scene_path+'/MTD_MSIL2A.xml')
metadata = dataset.GetMetadata()
# Out:
# /dss/dsshome1/06/di38laz/micromamba/envs/s2_dateline/lib/python3.13/site-packages/osgeo/gdal.py:311: FutureWarning: Neither gdal.UseExceptions() nor gdal.DontUseExceptions() has been explicitly called. In GDAL 4.0, exceptions will be enabled by default.
#   warnings.warn(

# %%
footprint = metadata.get("FOOTPRINT", "N/A")
footprint
# Out:
# 'POLYGON((180 70.27655361955614, 179.81353974733753 70.1729725023059, 179.5843586078059 70.04389269326435, 179.3585472875138 69.91458438853955, 179.13475573377443 69.78503878400527, 178.91353923 69.65517709587611, 178.69476259633996 69.52505546398446, 178.47855751966654 69.39473575765255, 178.26472185512287 69.26426455589153, 178.24780456916386 69.25384237584726, 177.9374906575181 69.24723897070908, 177.69674004388096 70.22784455372427, 180 70.27717192843326, -179.99884 70.27719672151753, 180 70.27655361955614))'

# %%
# Convert to a Shapely polygon
polygon = loads(footprint)
# Create a GeoDataFrame
gdf = gpd.GeoDataFrame(geometry=[polygon], crs="EPSG:4326")

# %%
gdf
# Out:
#                                             geometry
# 0  POLYGON ((180 70.27655, 179.81354 70.17297, 17...

# %%
gdf.total_bounds
# Out:
# array([-179.99884   ,   69.24723897,  180.        ,   70.27719672])

# %% [markdown]
# ### Plot the original geometry

# %%
gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f2501d8e372fc56b3fbfff890753bbe1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f2501d8e372fc56b3fbfff890753bbe1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f2501d8e372fc56b3fbfff890753bbe1 = L.map(
#                 &quot;map_f2501d8e372fc56b3fbfff890753bbe1&quot;,
#                 {
#                     center: [69.7622178461133, 0.0005799999999993588],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_f2501d8e372fc56b3fbfff890753bbe1);
#
#
#
#
#
#             var tile_layer_bf423ed3dfd818e466531ea8182ad345 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bf423ed3dfd818e466531ea8182ad345.addTo(map_f2501d8e372fc56b3fbfff890753bbe1);
#
#
#             map_f2501d8e372fc56b3fbfff890753bbe1.fitBounds(
#                 [[69.24723897070908, -179.99884], [70.27719672151753, 180.0]],
#                 {}
#             );
#
#
#         function geo_json_1fbb6a559b56969a2a5c0e824aa700ee_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_1fbb6a559b56969a2a5c0e824aa700ee_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_1fbb6a559b56969a2a5c0e824aa700ee_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_1fbb6a559b56969a2a5c0e824aa700ee_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_1fbb6a559b56969a2a5c0e824aa700ee_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_1fbb6a559b56969a2a5c0e824aa700ee.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_1fbb6a559b56969a2a5c0e824aa700ee_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_1fbb6a559b56969a2a5c0e824aa700ee = L.geoJson(null, {
#                 onEachFeature: geo_json_1fbb6a559b56969a2a5c0e824aa700ee_onEachFeature,
#
#                 style: geo_json_1fbb6a559b56969a2a5c0e824aa700ee_styler,
#                 pointToLayer: geo_json_1fbb6a559b56969a2a5c0e824aa700ee_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_1fbb6a559b56969a2a5c0e824aa700ee_add (data) {
#             geo_json_1fbb6a559b56969a2a5c0e824aa700ee
#                 .addData(data);
#         }
#             geo_json_1fbb6a559b56969a2a5c0e824aa700ee_add({&quot;bbox&quot;: [-179.99884, 69.24723897070908, 180.0, 70.27719672151753], &quot;features&quot;: [{&quot;bbox&quot;: [-179.99884, 69.24723897070908, 180.0, 70.27719672151753], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[180.0, 70.27655361955614], [179.81353974733753, 70.1729725023059], [179.5843586078059, 70.04389269326435], [179.3585472875138, 69.91458438853955], [179.13475573377443, 69.78503878400527], [178.91353923, 69.65517709587611], [178.

# %% [markdown]
# ### Plot the bounding box of the geometry

# %%
bbox = gdf.total_bounds

# %%
type(bbox)
# Out:
# numpy.ndarray

# %%
gdf_bbox = gpd.GeoDataFrame(
    {"geometry": [box(*bbox)]}, 
    crs=gdf.crs  # Use the CRS of the dataset
)

# %%
gdf_bbox.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c70adfdf3392208a389100baeae02e80 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c70adfdf3392208a389100baeae02e80&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c70adfdf3392208a389100baeae02e80 = L.map(
#                 &quot;map_c70adfdf3392208a389100baeae02e80&quot;,
#                 {
#                     center: [69.7622178461133, 0.0005799999999993588],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_c70adfdf3392208a389100baeae02e80);
#
#
#
#
#
#             var tile_layer_be87ec511952b3672371e382d17e8a0a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_be87ec511952b3672371e382d17e8a0a.addTo(map_c70adfdf3392208a389100baeae02e80);
#
#
#             map_c70adfdf3392208a389100baeae02e80.fitBounds(
#                 [[69.24723897070908, -179.99884], [70.27719672151753, 180.0]],
#                 {}
#             );
#
#
#         function geo_json_cd563dd1683351a0ac4a1f394b476ac2_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_cd563dd1683351a0ac4a1f394b476ac2_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_cd563dd1683351a0ac4a1f394b476ac2_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_cd563dd1683351a0ac4a1f394b476ac2_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_cd563dd1683351a0ac4a1f394b476ac2_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_cd563dd1683351a0ac4a1f394b476ac2.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_cd563dd1683351a0ac4a1f394b476ac2_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_cd563dd1683351a0ac4a1f394b476ac2 = L.geoJson(null, {
#                 onEachFeature: geo_json_cd563dd1683351a0ac4a1f394b476ac2_onEachFeature,
#
#                 style: geo_json_cd563dd1683351a0ac4a1f394b476ac2_styler,
#                 pointToLayer: geo_json_cd563dd1683351a0ac4a1f394b476ac2_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_cd563dd1683351a0ac4a1f394b476ac2_add (data) {
#             geo_json_cd563dd1683351a0ac4a1f394b476ac2
#                 .addData(data);
#         }
#             geo_json_cd563dd1683351a0ac4a1f394b476ac2_add({&quot;bbox&quot;: [-179.99884, 69.24723897070908, 180.0, 70.27719672151753], &quot;features&quot;: [{&quot;bbox&quot;: [-179.99884, 69.24723897070908, 180.0, 70.27719672151753], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[180.0, 69.24723897070908], [180.0, 70.27719672151753], [-179.99884, 70.27719672151753], [-179.99884, 69.24723897070908], [180.0, 69.24723897070908]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;

# %% [markdown]
# ## Apply fix to one example

# %%
gdf['geometry'].apply(crosses_dateline)
# Out:
# 0    True
# Name: geometry, dtype: bool

# %%
gdf_bbox['geometry'].apply(crosses_dateline)
# Out:
# 0    True
# Name: geometry, dtype: bool

# %%
gdf_corr = gdf['geometry'].apply(correct_dateline_crossing)

# %%
print(gdf.total_bounds)
print(gdf_corr.total_bounds)
# Out:
# [-179.99884      69.24723897  180.           70.27719672]
# [177.69674004  69.24723897 180.          70.27719672]

# %%
gdf_bbox_corr = gdf_bbox['geometry'].apply(correct_dateline_crossing)

# %%
print(gdf_bbox.total_bounds)
print(gdf_bbox_corr.total_bounds)
# Out:
# [-179.99884      69.24723897  180.           70.27719672]
# [-180.           69.24723897 -179.99884      70.27719672]

# %% [markdown]
# ### Plot the corrected geometry
# This fix looks good.

# %%
gdf_corr.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_24378bcf2057525e96d28307c98338f9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_24378bcf2057525e96d28307c98338f9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_24378bcf2057525e96d28307c98338f9 = L.map(
#                 &quot;map_24378bcf2057525e96d28307c98338f9&quot;,
#                 {
#                     center: [69.7622178461133, 178.84837002194047],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_24378bcf2057525e96d28307c98338f9);
#
#
#
#
#
#             var tile_layer_dfde0a2f395013e1a247e195d2ed7485 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dfde0a2f395013e1a247e195d2ed7485.addTo(map_24378bcf2057525e96d28307c98338f9);
#
#
#             map_24378bcf2057525e96d28307c98338f9.fitBounds(
#                 [[69.24723897070908, 177.69674004388096], [70.27719672151753, 180.0]],
#                 {}
#             );
#
#
#         function geo_json_475086cf7faea8882a7053d358ecdd7f_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_475086cf7faea8882a7053d358ecdd7f_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_475086cf7faea8882a7053d358ecdd7f_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_475086cf7faea8882a7053d358ecdd7f_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_475086cf7faea8882a7053d358ecdd7f_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_475086cf7faea8882a7053d358ecdd7f.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_475086cf7faea8882a7053d358ecdd7f_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_475086cf7faea8882a7053d358ecdd7f = L.geoJson(null, {
#                 onEachFeature: geo_json_475086cf7faea8882a7053d358ecdd7f_onEachFeature,
#
#                 style: geo_json_475086cf7faea8882a7053d358ecdd7f_styler,
#                 pointToLayer: geo_json_475086cf7faea8882a7053d358ecdd7f_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_475086cf7faea8882a7053d358ecdd7f_add (data) {
#             geo_json_475086cf7faea8882a7053d358ecdd7f
#                 .addData(data);
#         }
#             geo_json_475086cf7faea8882a7053d358ecdd7f_add({&quot;bbox&quot;: [177.69674004388096, 69.24723897070908, 180.0, 70.27719672151753], &quot;features&quot;: [{&quot;bbox&quot;: [177.69674004388096, 69.24723897070908, 180.0, 70.27719672151753], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[180.0, 70.27655361955614], [179.81353974733753, 70.1729725023059], [179.5843586078059, 70.04389269326435], [179.3585472875138, 69.91458438853955], [179.13475573377443, 69.78503878400527], [178.91353923, 69.6

# %% [markdown]
# ### Plot the corrected bbox geometry
# This doesn't make sense if the bbox is spanning the whole globe before. Better to correct the original geometry!

# %%
gdf_bbox_corr.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d2e26ec0220ad4337346b323660b4c96 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d2e26ec0220ad4337346b323660b4c96&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d2e26ec0220ad4337346b323660b4c96 = L.map(
#                 &quot;map_d2e26ec0220ad4337346b323660b4c96&quot;,
#                 {
#                     center: [69.7622178461133, -179.99942],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_d2e26ec0220ad4337346b323660b4c96);
#
#
#
#
#
#             var tile_layer_93a6b56d42471d424f458ead5d8e55af = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_93a6b56d42471d424f458ead5d8e55af.addTo(map_d2e26ec0220ad4337346b323660b4c96);
#
#
#             map_d2e26ec0220ad4337346b323660b4c96.fitBounds(
#                 [[69.24723897070908, -180.0], [70.27719672151753, -179.99884]],
#                 {}
#             );
#
#
#         function geo_json_9a15ff126aef781f30911715fc9a6f63_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_9a15ff126aef781f30911715fc9a6f63_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_9a15ff126aef781f30911715fc9a6f63_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_9a15ff126aef781f30911715fc9a6f63_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_9a15ff126aef781f30911715fc9a6f63_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_9a15ff126aef781f30911715fc9a6f63.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_9a15ff126aef781f30911715fc9a6f63_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_9a15ff126aef781f30911715fc9a6f63 = L.geoJson(null, {
#                 onEachFeature: geo_json_9a15ff126aef781f30911715fc9a6f63_onEachFeature,
#
#                 style: geo_json_9a15ff126aef781f30911715fc9a6f63_styler,
#                 pointToLayer: geo_json_9a15ff126aef781f30911715fc9a6f63_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_9a15ff126aef781f30911715fc9a6f63_add (data) {
#             geo_json_9a15ff126aef781f30911715fc9a6f63
#                 .addData(data);
#         }
#             geo_json_9a15ff126aef781f30911715fc9a6f63_add({&quot;bbox&quot;: [-180.0, 69.24723897070908, -179.99884, 70.27719672151753], &quot;features&quot;: [{&quot;bbox&quot;: [-180.0, 69.24723897070908, -179.99884, 70.27719672151753], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-180.0, 69.24723897070908], [-180.0, 70.27719672151753], [-179.99884, 70.27719672151753], [-179.99884, 69.24723897070908], [-180.0, 69.24723897070908]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;prope

# %% [markdown]
# ## Summary
# **Bbest to apply correction on footprint, not on bbox.**

# %% [markdown]
# # Apply fix to all known cases
# ## Get instances where error occurs
# ### via camunda

# %% [markdown]
# https://ingestion.terrabyte.lrz.de/camunda/app/cockpit/default/#/process-definition/sentinel-data-ingestion:1:db72cd6b-952f-11ef-8d59-0242ac120003/runtime?searchQuery=%5B%5D&viewbox=%7B%22Definitions_1bkjt5n%22:%7B%22x%22:-191.70461095100868,%22y%22:84.95244956772335,%22width%22:1962.536023054755,%22height%22:469.7406340057637%7D%7D

# %% [markdown]
# camunda -> sentinel data ingestion workflow -> Extract Metadata -> Incidents -> Metadata Error

# %% [markdown]
# ### globally
# would be good to run a check against the STAC API whether everything is ok there

# %%
## why is antimeridian and the solution in place not solving this --> see comment: 

#stactools-sentinel2/src/stactools/sentinel2/stac.py at main · DLR-terrabyte/stactools-sentinel2
#https://stac.dataspace.copernicus.eu/v1/collections/sentinel-2-l2a/items/S2A_MSIL2A_20230409T002611_N0509_R102_T01WCT_20230409T040056 
#https://browser.stac.dataspace.copernicus.eu/collections/sentinel-2-l2a/items/S2A_MSIL2A_20230409T002611_N0509_R102_T01WCT_20230409T040056?.language=de

# %% [markdown]
# ### Make instance list

# %%
# manual for testing
scene_list = ['/dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CT/2023/04/S2A_MSIL2A_20230409T002611_N0509_R102_T01WCT_20230409T040056.SAFE', 
              '/dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CT/2023/04/S2A_MSIL2A_20230409T002611_N0509_R102_T01WCT_20230409T040056.SAFE']

# %%
# extracted by Jonas M. via camunda scraping tool (got all metadata errors, this list does not only contain dateline errors)
scene_list = []
sen3_list = []

with open('camunda_sentinel_ingestion_errors_20250522.txt', 'r') as f:
    for line in f:
        filename = line.strip()
        if not filename:
            continue  # skip empty lines
        if filename.lower().endswith('.safe'):
            scene_list.append(filename)
        elif filename.lower().endswith('.sen3'):
            sen3_list.append(filename)

# print counts
print(f"SAFE files: {len(scene_list)}")
print(f"SEN3 files: {len(sen3_list)}")
# Out:
# SAFE files: 45
# SEN3 files: 8

# %% [markdown]
# ## Convenience functions to  facilitate looping through cases

# %%
#get footprint
#check if crossing --> defined above: crosses_dateline
#apply fix --> defined above: correct_dateline_crossing
#return
#visualize before and after

def get_footprint(scene_path):
    # get footprint from metadata
    dataset = gdal.Open(scene_path+'/MTD_MSIL2A.xml')
    metadata = dataset.GetMetadata()
    footprint = metadata.get("FOOTPRINT", "N/A")
    # Convert to a Shapely polygon and Create a GeoDataFrame
    polygon = loads(footprint)
    gdf = gpd.GeoDataFrame(geometry=[polygon], crs="EPSG:4326")
    #print(gdf)
    return(gdf)

def make_bbox(gdf):
    bbox = gdf.total_bounds
    gdf_bbox = gpd.GeoDataFrame(
        {"geometry": [box(*bbox)]}, 
        crs=gdf.crs
    )
    #print(gdf_bbox)
    return(gdf_bbox)

def check_and_correct(scene_path):
    print(f"Processing: {scene_path}")
    gdf = get_footprint(scene_path)
    gdf_bbox = make_bbox(gdf)

    # Default empty GeoDataFrames for no-correction case
    empty_gdf = gpd.GeoDataFrame(geometry=[], crs="EPSG:4326")

    # Check if correction is needed
    if gdf['geometry'].apply(crosses_dateline).any() or gdf_bbox['geometry'].apply(crosses_dateline).any():
        print("Correction needed. Applying fix.")
        # Correct dateline crossing
        corrected_geoms = gdf['geometry'].apply(correct_dateline_crossing)
        gdf_corr = gpd.GeoDataFrame(geometry=corrected_geoms, crs="EPSG:4326")
        gdf_corr_bbox = make_bbox(gdf_corr)
    else:
        print("No correction needed.")
        gdf_corr = empty_gdf
        gdf_corr_bbox = empty_gdf

    return gdf, gdf_bbox, gdf_corr, gdf_corr_bbox

# %% [markdown]
# ## Apply fix to all cases

# %%
results = {} 
for scene_path in scene_list:
    gdf, gdf_bbox, gdf_corr, gdf_corr_bbox = check_and_correct(scene_path)
    results[scene_path] = {"gdf": gdf, "gdf_bbox": gdf_bbox, "gdf_corr": gdf_corr, "gdf_corr_bbox": gdf_corr_bbox}
# Out:
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/32/S/QD/2025/05/S2B_MSIL2A_20250514T100029_N0511_R122_T32SQD_20250514T135713.SAFE
# No correction needed.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CM/2018/04/S2A_MSIL2A_20180405T235621_N0500_R116_T01WCM_20230730T095628.SAFE
# Correction needed. Applying fix.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CM/2022/06/S2A_MSIL2A_20220603T235621_N0510_R116_T01WCM_20240615T221507.SAFE
# Correction needed. Applying fix.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CM/2021/04/S2A_MSIL2A_20210409T235611_N0500_R116_T01WCM_20230510T190456.SAFE
# Correction needed. Applying fix.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CM/2018/06/S2B_MSIL2A_20180629T235619_N0500_R116_T01WCM_20230724T053921.SAFE
# Correction needed. Applying fix.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CM/2018/10/S2A_MSIL2A_20181002T235611_N0500_R116_T01WCM_20230620T035412.SAFE
# Correction needed. Applying fix.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CM/2021/09/S2A_MSIL2A_20210926T235621_N0500_R116_T01WCM_20230116T171320.SAFE
# Correction needed. Applying fix.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CM/2019/11/S2B_MSIL2A_20191101T235739_N0500_R116_T01WCM_20230610T050742.SAFE
# Correction needed. Applying fix.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CM/2018/10/S2A_MSIL2A_20181012T235611_N0500_R116_T01WCM_20230709T043308.SAFE
# Correction needed. Applying fix.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CM/2018/07/S2A_MSIL2A_20180704T235621_N0500_R116_T01WCM_20230712T184907.SAFE
# Correction needed. Applying fix.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CM/2017/04/S2A_MSIL2A_20170420T235621_N0500_R116_T01WCM_20230920T031635.SAFE
# Correction needed. Applying fix.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CT/2023/09/S2B_MSIL2A_20230911T002609_N0510_R102_T01WCT_20241030T051806.SAFE
# Correction needed. Applying fix.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CM/2020/08/S2A_MSIL2A_20200802T235621_N0500_R116_T01WCM_20230320T064150.SAFE
# Correction needed. Applying fix.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CM/2021/04/S2B_MSIL2A_20210414T235609_N0500_R116_T01WCM_20230509T133656.SAFE
# Correction needed. Applying fix.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CM/2018/09/S2B_MSIL2A_20180907T235609_N0500_R116_T01WCM_20230710T051453.SAFE
# Correction needed. Applying fix.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CM/2020/04/S2B_MSIL2A_20200409T235609_N0500_R116_T01WCM_20230412T150325.SAFE
# Correction needed. Applying fix.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/35/U/PB/2025/05/S2B_MSIL2A_20250512T092029_N0511_R093_T35UPB_20250512T122448.SAFE
# No correction needed.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CM/2018/07/S2B_MSIL2A_20180709T235619_N0500_R116_T01WCM_20230814T080133.SAFE
# Correction needed. Applying fix.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/51/S/UA/2025/05/S2B_MSIL2A_20250515T024529_N0511_R132_T51SUA_20250515T044956.SAFE
# No correction needed.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/48/R/UN/2025/05/S2C_MSIL2A_20250515T033551_N0511_R061_T48RUN_20250515T091314.SAFE
# No correction needed.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/37/X/DC/2025/05/S2C_MSIL2A_20250513T093601_N0511_R036_T37XDC_20250513T111009.SAFE
# No correction needed.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CM/2020/10/S2B_MSIL2A_20201026T235709_N0500_R116_T01WCM_20230325T133039.SAFE
# Correction needed. Applying fix.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CM/2023/10/S2A_MSIL2A_20231006T235611_N0509_R116_T01WCM_20231007T010352.SAFE
# Correction needed. Applying fix.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CM/2021/07/S2A_MSIL2A_20210718T235621_N0500_R116_T01WCM_20230826T000545.SAFE
# Correction needed. Applying fix.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CM/2018/07/S2B_MSIL2A_20180719T235619_N0500_R116_T01WCM_20230713T012051.SAFE
# Correction needed. Applying fix.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CM/2021/05/S2B_MSIL2A_20210524T235619_N0500_R116_T01WCM_20230221T222341.SAFE
# Correction needed. Applying fix.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CM/2019/03/S2A_MSIL2A_20190301T235611_N0500_R116_T01WCM_20221120T173015.SAFE
# Correction needed. Applying fix.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CT/2025/05/S2B_MSIL2A_20250513T002609_N0511_R102_T01WCT_20250513T015442.SAFE
# Correction needed. Applying fix.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CM/2021/03/S2B_MSIL2A_20210325T235619_N0500_R116_T01WCM_20230511T054502.SAFE
# Correction needed. Applying fix.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CM/2020/03/S2A_MSIL2A_20200325T235611_N0500_R116_T01WCM_20230409T192836.SAFE
# Correction needed. Applying fix.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CT/2022/09/S2A_MSIL2A_20220921T002621_N0510_R102_T01WCT_20240722T055214.SAFE
# Correction needed. Applying fix.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CM/2023/08/S2B_MSIL2A_20230802T235619_N0509_R116_T01WCM_20230803T002530.SAFE
# Correction needed. Applying fix.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CM/2019/06/S2A_MSIL2A_20190619T235621_N0500_R116_T01WCM_20230623T202205.SAFE
# Correction needed. Applying fix.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CM/2020/04/S2A_MSIL2A_20200424T235621_N0500_R116_T01WCM_20230409T194255.SAFE
# Correction needed. Applying fix.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CM/2023/05/S2A_MSIL2A_20230509T235611_N0509_R116_T01WCM_20230510T024259.SAFE
# Correction needed. Applying fix.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CT/2023/09/S2B_MSIL2A_20230911T002609_N0509_R102_T01WCT_20230911T022654.SAFE
# Correction needed. Applying fix.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CM/2023/06/S2B_MSIL2A_20230623T235619_N0509_R116_T01WCM_20230624T003430.SAFE
# Correction needed. Applying fix.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CT/2024/04/S2B_MSIL2A_20240418T002609_N0510_R102_T01WCT_20240418T020637.SAFE
# Correction needed. Applying fix.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/22/L/FJ/2025/03/S2C_MSIL2A_20250330T133901_N0511_R124_T22LFJ_20250330T201214.SAFE
# No correction needed.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CM/2018/11/S2A_MSIL2A_20181101T235731_N0500_R116_T01WCM_20230621T013512.SAFE
# Correction needed. Applying fix.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CM/2021/04/S2B_MSIL2A_20210404T235619_N0500_R116_T01WCM_20230509T173315.SAFE
# Correction needed. Applying fix.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CM/2018/05/S2A_MSIL2A_20180525T235621_N0500_R116_T01WCM_20230724T072116.SAFE
# Correction needed. Applying fix.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CT/2023/04/S2A_MSIL2A_20230409T002611_N0509_R102_T01WCT_20230409T040056.SAFE
# Correction needed. Applying fix.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CM/2018/04/S2A_MSIL2A_20180415T235621_N0500_R116_T01WCM_20230811T103040.SAFE
# Correction needed. Applying fix.
# Processing: /dss/dsstbyfs01/pn56su/pn56su-dss-0008/Sentinel-2-Col-1/L2A/tiles/01/W/CM/2020/09/S2A_MSIL2A_20200921T235621_N0500_R116_T01WCM_20230401T113250.SAFE
# Correction needed. Applying fix.

# %% [markdown]
# ### Plot case by case to check if all corrections make sense
# Change the index, use the layer control in the map to switch the layers on and off.

# %%
index = 12 # change index here to explore
scene_keys = list(results.keys())
key = scene_keys[index]
gdf = results[key]["gdf"]
gdf_bbox = results[key]["gdf_bbox"]
gdf_corr = results[key]["gdf_corr"]
gdf_corr_bbox = results[key]["gdf_corr_bbox"]

# Plot gdf_corr (blue) and gdf_corr_bbox (red)
m = gdf_corr.explore(color="blue", name="gdf_corr")
gdf_corr_bbox.explore(m=m, color="red", name="gdf_corr_bbox")
gdf.explore(m=m, color="green", name="gdf")
gdf_bbox.explore(m=m, color='yellow', name="gdf_bbox")
m.add_child(folium.LayerControl())
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_edf88bcb98018e14062a4a33eff54ebd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_edf88bcb98018e14062a4a33eff54ebd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_edf88bcb98018e14062a4a33eff54ebd = L.map(
#                 &quot;map_edf88bcb98018e14062a4a33eff54ebd&quot;,
#                 {
#                     center: [64.38547416411376, 179.38888913421164],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_edf88bcb98018e14062a4a33eff54ebd);
#
#
#
#
#
#             var tile_layer_e42262b76dd51c9188b400018b0896a4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e42262b76dd51c9188b400018b0896a4.addTo(map_edf88bcb98018e14062a4a33eff54ebd);
#
#
#             map_edf88bcb98018e14062a4a33eff54ebd.fitBounds(
#                 [[63.88152370940929, 178.77777826842325], [64.88942461881823, 180.0]],
#                 {}
#             );
#
#
#         function geo_json_bfb7542d3e46007e3c7b61be8392ad99_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_bfb7542d3e46007e3c7b61be8392ad99_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_bfb7542d3e46007e3c7b61be8392ad99_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_bfb7542d3e46007e3c7b61be8392ad99_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_bfb7542d3e46007e3c7b61be8392ad99_onEach

# %% [markdown]
# ### Check tiles that are affected
# It seems as if mostly the same tiles are affected.

# %%
# check if geometry was corrected
def is_corrected(gdf_corr):
    if gdf_corr is None:
        return False
    # If gdf_corr is a GeoSeries (from .apply), wrap it
    if isinstance(gdf_corr, gpd.GeoSeries):
        gdf_corr = gpd.GeoDataFrame(geometry=gdf_corr, crs="EPSG:4326")
    if not isinstance(gdf_corr, gpd.GeoDataFrame):
        return False
    # Check that it has at least one non-empty, non-null geometry
    return (
        gdf_corr.geometry.notnull().any() and
        not gdf_corr.geometry.is_empty.all()
    )

# Build correction summary
rows = []

for scene_path, geoms in results.items():
    filename = scene_path.split("/")[-1]
    parts = filename.split("_")

    N = next((p for p in parts if p.startswith("N") and len(p) == 5), None)
    R = next((p for p in parts if p.startswith("R") and len(p) == 4), None)
    T = next((p for p in parts if p.startswith("T") and len(p) == 6), None)

    gdf_corr = geoms.get("gdf_corr")
    correction_status = "Corrected" if is_corrected(gdf_corr) else "Not Corrected"

    rows.append((N, R, T, correction_status))

df = pd.DataFrame(rows, columns=["N", "R", "T", "Correction Status"])
summary = df.value_counts().reset_index(name="Count").sort_values("Count", ascending=False)

print(summary)
# Out:
#         N     R       T Correction Status  Count
# 0   N0500  R116  T01WCM         Corrected     28
# 1   N0509  R116  T01WCM         Corrected      4
# 2   N0510  R102  T01WCT         Corrected      3
# 3   N0509  R102  T01WCT         Corrected      2
# 4   N0510  R116  T01WCM         Corrected      1
# 5   N0511  R036  T37XDC     Not Corrected      1
# 6   N0511  R061  T48RUN     Not Corrected      1
# 7   N0511  R093  T35UPB     Not Corrected      1
# 8   N0511  R102  T01WCT         Corrected      1
# 9   N0511  R122  T32SQD     Not Corrected      1
# 10  N0511  R124  T22LFJ     Not Corrected      1
# 11  N0511  R132  T51SUA     Not Corrected      1

# %% [markdown]
# # Integrate fix
# ## Decide where to apply fix
# I would suggest adding the code after the part where the stac tools function `create_item()` is checking if the area is too large. If this error triggers the correction should be applied to the footprint. And the bbox has to be extracted again.
#
# Integrate here: https://github.com/DLR-terrabyte/stactools-sentinel2/blob/main/src/stactools/sentinel2/stac.py#L137
#
# ```
# # sometimes, antimeridian and/or polar crossing scenes on some platforms end up
# # with geometries that cover the inverse area that they should, so nearly the
# # entire globe. This has been seen to have different behaviors on different
# # architectures and dependent library versions. To prevent these errors from
# # resulting in a wildly-incorrect geometry, we fail here if the geometry
# # is unreasonably large. Typical areas will no greater than 3, whereas an
# # incorrect globe-covering geometry will have an area for 61110.
#
# if (ga := geometry.area) > 100:
#     raise Exception(f"Area of geometry is {ga}, which is too large to be correct.")
#
# bbox = [round(v, COORD_ROUNDING) for v in antimeridian.bbox(geometry)]
#
# ```

# %% [markdown]
# ### Suggested fix
# Needs testing when integrated in package.
#
# - Make the function `crosses_dateline()` and `correct_dateline_crossing()` available to the package.
# - Check if geom is crossing dateline and is currently too large --> Fix
# - Check if geom is still too large --> If yes break.
# - Check if geom is still crossing dateline --> If yes break.
# - Make the bbox of the geom

# %% [markdown]
# ```
# if (ga := geometry.area) > 100 & (crosses_dateline(geometry)):
#     raise Warning(f"Geometry is crossing the dateline and area of geometry is {ga}, which is too large to be correct. It will be corrected.")
#     geometry = correct_dateline_crossing(geometry)
#
# if (ga := geometry.area) > 100:
#     raise Execption(f"Area of geometry is {ga}, which is too large to be correct.")
#
# if (crosses_dateline(geometry)) :
#     raise Exception(f"Geometry is still crossing the dateline."
#
# # i don't know what this is actually doing? I guess it is creating the bbox from the geometry.
# # i guess antimeridian.bbox(geometry) makes a bbox and returns it as a list [xmin, ymin, xmax), ymax] (https://github.com/gadomski/antimeridian/blob/main/src/antimeridian/_implementation.py#L748)
# # bbox = [round(v, COORD_ROUNDING) for v in antimeridian.bbox(geometry)]
#
# # We also still have to do that
# bbox = [round(v, COORD_ROUNDING) for v in geometry.total_bounds]
# ```

# %% [markdown]
# **Quick test on behavior of creating bbox**

# %%
gdf.geometry.total_bounds
# Out:
# array([-179.9997    ,   63.88152371,  180.        ,   64.88942462])

# %%
[round(v, 0) for v in gdf.geometry.total_bounds]
# Out:
# [np.float64(-180.0), np.float64(64.0), np.float64(180.0), np.float64(65.0)]
